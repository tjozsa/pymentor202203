# %% [markdown]
# # 1. feladatsor - tuple
#
# ## Tuple módosítás
# Írj egy Python programot ami "kitörli" egy Tuple utolsó elemét. (Mivel a tuple-t nem lehet modositani ezert kreativnak kell lenned. Mondhatjuk úgy is, hogy készíts a kiinduálsi tuple felhasználásával egy újat programozottan ami nem tartalmazza az eredeti tuple utolsó elemét)

# %%
tuplex = "w", 3, "r", "s", "o", "u", "r", "c", "e"
### BEGIN SOLUTION
### END SOLUTION

# %% [markdown]
# ## Lista elemek szűrése
#
# Adott az alábbi lista
#
# `sample_list = [87, 45, 41, 65, 94, 41, 99, 94]`
#
# Távolítsuk el a duplikált elemeket belőle. Az így keletkezett listából készítsünk egy Tuple-t `result` néven. Írjuk ki a képernyőre.
#
# Keressük meg a Tuple minimum és maximúm értéket. Ezeket írjuk ki a képernyőre.

# %%
sample_list = [87, 52, 44, 53, 54, 87, 52, 53]
result = None
### BEGIN SOLUTION

### END SOLUTION
